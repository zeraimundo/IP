# %% [markdown]
# <a href="https://colab.research.google.com/github/zeraimundo/IP_Exercicio_05042021/blob/main/C%C3%B3pia_de_Jos%C3%A9_Raimundo_Bezerra_de_Carvalho_Programa%C3%A7%C3%A3o_e_Estrutura_de_Dados_%C3%81rvores_Bin%C3%A1rias_de_Busca_Atividade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Árvores Binárias de Busca - Atividade

# %% [markdown]
# # 1. Considere a seguinte expressão aritmética e realize as ações pedidas a seguir (obrigatória)
#
# ## (12 + (10 * ((20/2) - 7)))
# ### Representação em árvore dessa expressão:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# a. Implemente um código python que represente a árvore binária contendo esses elementos. Crie as classes `No`, contendo os apontadores para os elementos da `esquerda` e `direita` e a classe `ArvoreBinaria` contendo a referência para o elemento `raiz`. \\
# b. Crie um método para navegar na árvore e exibir a expressão matemática. Neste caso, utilize o que você aprendeu sobre os métodos de navegação (pré-ordem, in-ordem ou pós-ordem) para exibir os parênteses da esquerda, os parênteses da direita e o valor de cada nó. \\
# c. Crie um método para calcular o valor resultante da expressão.

# %%
# a.

# %%
# b.

# %%
# c.

# %% [markdown]
# ---------

# %% [markdown]
# ## 2. Construa um método para verificar se duas árvores binárias A e B são identicas

# %% [markdown]
# ## 3. Crie um método para calcular a altura de uma árvore binária de busca

# %% [markdown]
# ## 4. Implemente um método que identifique se uma árvore binária é simétrica. Uma árvore é simétrica se a subárvore esquerda for um espelho da subárvore direita. A figura abaixo mostra uma árvore simétrica, na parte a), e uma árvore não simétrica, na parte b).
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 5. Escreva um algoritmo que verifica se uma dada árvore binária é do tipo AVL. Suponha já existente uma função que retorna a altura de uma árvore binária (questão 3)
